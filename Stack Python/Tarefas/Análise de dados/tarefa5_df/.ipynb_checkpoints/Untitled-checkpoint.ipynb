# %%
import pandas as pd
import numpy as np

# %%
dados_paises = pd.read_csv("paises.csv", sep=";")
dados_paises
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# # 1 a, b

# %%
sem_espacos = dados_paises['Country'].str.strip()
nova_coluna = pd.Series([], dtype="object")
nova_coluna = dados_paises['Country'].str.strip()
paises_oceania = dados_paises.filter(items=['Country']).where(dados_paises['Region'] == 'OCEANIA                            ')
paises_oceania = paises_oceania.dropna()
paises_oceania
# Out:
#                    Country
# 3          American Samoa
# 11              Australia
# 47           Cook Islands
# 67                   Fiji
# 71       French Polynesia
# 83                   Guam
# 108              Kiribati
# 130      Marshall Islands
# 136  Micronesia, Fed. St.
# 144                 Nauru
# 148         New Caledonia
# 149           New Zealand
# 153    N. Mariana Islands
# 157                 Palau
# 159      Papua New Guinea
# 176                 Samoa
# 187       Solomon Islands
# 203                 Tonga
# 209                Tuvalu
# 217               Vanuatu
# 221     Wallis and Futuna

# %%
qnt_paises_oceania = paises_oceania.count()
qnt_paises_oceania
# Out:
# Country    21
# dtype: int64

# %% [markdown]
# # 2

# %%
maior = dados_paises['Population'].max()
dados_paises.filter(items=['Region', 'Country']).where(dados_paises['Population'] == maior).dropna()
# Out:
#                            Region Country
# 42  ASIA (EX. NEAR EAST)           China

# %% [markdown]
# # 3

# %%
total = dados_paises['Literacy (%)'].mean()
dados_paises.filter(items=['Region', 'Literacy (%)']).groupby('Region').mean()
# Out:
#                                      Literacy (%)
# Region
# ASIA (EX. NEAR EAST)                    79.553571
# BALTICS                                 99.733333
# C.W. OF IND. STATES                     98.725000
# EASTERN EUROPE                          72.816667
# LATIN AMER. & CARIB                     88.640000
# NEAR EAST                               69.581250
# NORTHERN AFRICA                         56.033333
# NORTHERN AMERICA                        78.200000
# OCEANIA                                 71.914286
# SUB-SAHARAN AFRICA                      61.284314
# WESTERN EUROPE                          80.821429

# %% [markdown]
# # 4

# %%
pais_costa = dados_paises.filter(items=['Country']).where(dados_paises['Coastline (coast/area ratio)'] == 0)
pais_costa = pais_costa.dropna()
pais_costa
# Out:
#                    Country
# 0             Afghanistan
# 4                 Andorra
# 9                 Armenia
# 12                Austria
# 13             Azerbaijan
# 18                Belarus
# 23                 Bhutan
# 24                Bolivia
# 26               Botswana
# 31           Burkina Faso
# 33                Burundi
# 39   Central African Rep.
# 40                   Chad
# 45       Congo, Dem. Rep.
# 53         Czech Republic
# 65               Ethiopia
# 92                Hungary
# 106            Kazakhstan
# 112            Kyrgyzstan
# 113                  Laos
# 116               Lesotho
# 119         Liechtenstein
# 121            Luxembourg
# 123             Macedonia
# 125                Malawi
# 128                  Mali
# 137               Moldova
# 139              Mongolia
# 145                 Nepal
# 151                 Niger
# 160              Paraguay
# 170                Rwanda
# 177            San Marino
# 181                Serbia
# ...

# %%
nomes.to_csv('noCoast.csv')

# %% [markdown]
# # 5

# %%
dados_paises['Humanitarian Help'] = np.where(dados_paises['Deathrate'] < 9, "balanced", "Urgent")
dados_paises
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...
